# %%
from tools.tools_preprocessing import *
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From e:\CentraleSupelec\Vision\sign_language_recognition\venv_slr\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def loadImage(src, show = True):
    img=cv2.imread(src,1)
    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    if show : 
        plt.imshow(rgb,interpolation='nearest')
        plt.show()
    return rgb

# %%
path_A = 'dataset/asl_alphabet_train/A/8.jpg'

img = loadImage(path_A)

# %%
img_gray = gray_scale(img)
img_canny = canny_detector(img_gray, 20, 100)
plot_canny_img(img, img_canny)

# %%
path_clean = 'dataset/asl_alphabet_train_clean/A/8.png'
img_clean = loadImage(path_clean, show = False)

img_clean_gray = gray_scale(img_clean)
img_clean_canny = canny_detector(img_clean_gray, 40, 100)
plot_canny_img(img_clean, img_clean_canny)

# %%
img = loadImage(path_A, show = False)
img_gray = gray_scale(img)
img_laplacian = laplacian_detector(img_gray)
sobelx = sobelx_detector(img_gray)
sobely = sobely_detector(img_gray)

plt.subplot(2,2,1),plt.imshow(img_gray,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(img_laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
